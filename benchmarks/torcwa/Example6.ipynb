# %%
'''
TORCWA Example6
Topology optimization - Maximize 1st order diffraction

'''
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# Import
import numpy as np
import torch
import scipy.io
from matplotlib import pyplot as plt
import time

import torcwa
import Materials

# Hardware
# If GPU support TF32 tensor core, the matmul operation is faster than FP32 but with less precision.
# If you need accurate operation, you have to disable the flag below.
torch.backends.cuda.matmul.allow_tf32 = False
sim_dtype = torch.complex64
geo_dtype = torch.float32
device = torch.device('cuda')

# Simulation environment
# light
lamb0 = torch.tensor(532.,dtype=geo_dtype,device=device)    # nm
inc_ang = 0.*(np.pi/180)    # radian
azi_ang = 0.*(np.pi/180)    # radian

# material
substrate_eps = 1.46**2
silicon_eps = Materials.aSiH.apply(lamb0)**2

# geometry
L = [700., 300.]            # nm / nm
torcwa.rcwa_geo.dtype = geo_dtype
torcwa.rcwa_geo.device = device
torcwa.rcwa_geo.Lx = L[0]
torcwa.rcwa_geo.Ly = L[1]
torcwa.rcwa_geo.nx = 700
torcwa.rcwa_geo.ny = 300
torcwa.rcwa_geo.grid()
torcwa.rcwa_geo.edge_sharpness = 1000.

x_axis = torcwa.rcwa_geo.x.cpu()
y_axis = torcwa.rcwa_geo.y.cpu()

# layers
layer0_thickness = 300.

# %%
# Objective function
def objective_function(rho):
    order = [15,8]

    sim = torcwa.rcwa(freq=1/lamb0,order=order,L=L,dtype=sim_dtype,device=device)
    sim.add_input_layer(eps=substrate_eps)
    sim.set_incident_angle(inc_ang=inc_ang,azi_ang=azi_ang)
    layer0_eps = rho*silicon_eps + (1.-rho)
    sim.add_layer(thickness=layer0_thickness,eps=layer0_eps)
    sim.solve_global_smatrix()
    t1xx = sim.S_parameters(orders=[1,0],direction='forward',port='transmission',polarization='xx',ref_order=[0,0])
    t1yy = sim.S_parameters(orders=[1,0],direction='forward',port='transmission',polarization='yy',ref_order=[0,0])
    t1xy = sim.S_parameters(orders=[1,0],direction='forward',port='transmission',polarization='xy',ref_order=[0,0])
    t1yx = sim.S_parameters(orders=[1,0],direction='forward',port='transmission',polarization='yx',ref_order=[0,0])

    T1_sum = torch.abs(t1xx)**2 + torch.abs(t1yy)**2 + torch.abs(t1xy)**2 + torch.abs(t1yx)**2
    return T1_sum

# %%
# Perform optimization
# optimizer parameters for ADAM optimizer
iter_max = 800
beta = np.exp(np.arange(start=0,stop=iter_max)*np.log(1000)/iter_max)

# blur kernel
blur_radius = 20.
dx, dy = L[0]/torcwa.rcwa_geo.nx, L[1]/torcwa.rcwa_geo.ny
x_kernel_axis = (torch.arange(torcwa.rcwa_geo.nx,dtype=geo_dtype,device=device)-(torcwa.rcwa_geo.nx-1)/2)*dx
y_kernel_axis = (torch.arange(torcwa.rcwa_geo.ny,dtype=geo_dtype,device=device)-(torcwa.rcwa_geo.ny-1)/2)*dy
x_kernel_grid, y_kernel_grid = torch.meshgrid(x_kernel_axis,y_kernel_axis,indexing='ij')
g = torch.exp(-(x_kernel_grid**2+y_kernel_grid**2)/blur_radius**2)
g = g/torch.sum(g)
g_fft = torch.fft.fftshift(torch.fft.fft2(torch.fft.ifftshift(g)))

torch.manual_seed(333)
rho = torch.rand((torcwa.rcwa_geo.nx,torcwa.rcwa_geo.ny),dtype=geo_dtype,device=device)

#is it needed?
rho = (rho + torch.fliplr(rho))/2
rho_fft = torch.fft.fftshift(torch.fft.fft2(torch.fft.ifftshift(rho)))
rho = torch.real(torch.fft.fftshift(torch.fft.ifft2(torch.fft.ifftshift(rho_fft*g_fft))))
#

# %%
rho.requires_grad_(True)
optimizer = torch.optim.Adam([rho], lr = 0.001)

# %%
def rho_preprocess(rho):
    rho = rho.clip(0,1)
    rho = (rho + torch.fliplr(rho))/2
    return rho

# %%
rho_history = []
FoM_history = []

start_time = time.time()
for it in range(0,iter_max):
    preprocessed_rho = rho_preprocess(rho)
    rho_fft = torch.fft.fftshift(torch.fft.fft2(torch.fft.ifftshift(preprocessed_rho)))

    rho_bar = torch.real(torch.fft.fftshift(torch.fft.ifft2(torch.fft.ifftshift(rho_fft*g_fft))))
    rho_tilda = 1/2 + torch.tanh(2*beta[it]*rho_bar-beta[it])/(2*np.math.tanh(beta[it]))
    FoM = objective_function(rho_tilda)
    
    optimizer.zero_grad()
    (-FoM).backward() #gradient ascent
    optimizer.step()
    
    rho_history.append(rho_tilda.detach().cpu().numpy())
    FoM_history.append(float(FoM.detach().cpu().numpy()))
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print('Iteration:',it,'/ FoM:',int(FoM*10000)/10000,'/ Elapsed time:',str(int(elapsed_time))+' s')
# Out:
# Iteration: 0 / FoM: 0.0 / Elapsed time: 2 s
# Iteration: 1 / FoM: 0.0001 / Elapsed time: 4 s
# Iteration: 2 / FoM: 0.0003 / Elapsed time: 5 s
# Iteration: 3 / FoM: 0.0006 / Elapsed time: 7 s
# Iteration: 4 / FoM: 0.0009 / Elapsed time: 8 s
# Iteration: 5 / FoM: 0.0014 / Elapsed time: 10 s
# Iteration: 6 / FoM: 0.002 / Elapsed time: 11 s
# Iteration: 7 / FoM: 0.0026 / Elapsed time: 13 s
# Iteration: 8 / FoM: 0.0034 / Elapsed time: 15 s
# Iteration: 9 / FoM: 0.0044 / Elapsed time: 17 s
# Iteration: 10 / FoM: 0.0054 / Elapsed time: 19 s
# Iteration: 11 / FoM: 0.0066 / Elapsed time: 20 s
# Iteration: 12 / FoM: 0.0079 / Elapsed time: 22 s
# Iteration: 13 / FoM: 0.0094 / Elapsed time: 24 s
# Iteration: 14 / FoM: 0.011 / Elapsed time: 26 s
# Iteration: 15 / FoM: 0.0128 / Elapsed time: 28 s
# Iteration: 16 / FoM: 0.0148 / Elapsed time: 30 s
# Iteration: 17 / FoM: 0.0169 / Elapsed time: 31 s
# Iteration: 18 / FoM: 0.0193 / Elapsed time: 33 s
# Iteration: 19 / FoM: 0.0218 / Elapsed time: 35 s
# Iteration: 20 / FoM: 0.0246 / Elapsed time: 36 s
# Iteration: 21 / FoM: 0.0276 / Elapsed time: 37 s
# Iteration: 22 / FoM: 0.0308 / Elapsed time: 39 s
# Iteration: 23 / FoM: 0.0343 / Elapsed time: 40 s
# Iteration: 24 / FoM: 0.038 / Elapsed time: 42 s
# Iteration: 25 / FoM: 0.0419 / Elapsed time: 43 s
# Iteration: 26 / FoM: 0.0461 / Elapsed time: 45 s
# Iteration: 27 / FoM: 0.0506 / Elapsed time: 46 s
# Iteration: 28 / FoM: 0.0554 / Elapsed time: 47 s
# Iteration: 29 / FoM: 0.0604 / Elapsed time: 49 s
# Iteration: 30 / FoM: 0.0658 / Elapsed time: 50 s
# Iteration: 31 / FoM: 0.0715 / Elapsed time: 51 s
# Iteration: 32 / FoM: 0.0774 / Elapsed time: 53 s
# Iteration: 33 / FoM: 0.0837 / Elapsed time: 54 s
# Iteration: 34 / FoM: 0.0903 / Elapsed time: 56 s
# Iteration: 35 / FoM: 0.0972 / Elapsed time: 57 s
# Iteration: 36 / FoM: 0.1045 / Elapsed time: 58 s
# Iteration: 37 / FoM: 0.112 / Elapsed time: 60 s
# Iteration: 38 / FoM: 0.12 / Elapsed time: 61 s
# Iteration: 39 / FoM: 0.1282 / Elapsed time: 62 s
# Iteration: 40 / FoM: 0.1368 / Elapsed time: 64 s
# Iteration: 41 / FoM: 0.1457 / Elapsed time: 65 s
# Iteration: 42 / FoM: 0.1549 / Elapsed time: 66 s
# Iteration: 43 / FoM: 0.1645 / Elapsed time: 68 s
# Iteration: 44 / FoM: 0.1744 / Elapsed time: 69 s
# Iteration: 45 / FoM: 0.1846 / Elapsed time: 70 s
# Iteration: 46 / FoM: 0.1952 / Elapsed time: 72 s
# Iteration: 47 / FoM: 0.2062 / Elapsed time: 73 s
# Iteration: 48 / FoM: 0.2174 / Elapsed time: 74 s
# Iteration: 49 / FoM: 0.229 / Elapsed time: 76 s
# Iteration: 50 / FoM: 0.2411 / Elapsed time: 77 s
# Iteration: 51 / FoM: 0.2535 / Elapsed time: 78 s
# Iteration: 52 / FoM: 0.2663 / Elapsed time: 80 s
# Iteration: 53 / FoM: 0.2796 / Elapsed time: 81 s
# Iteration: 54 / FoM: 0.2933 / Elapsed time: 82 s
# Iteration: 55 / FoM: 0.3075 / Elapsed time: 84 s
# Iteration: 56 / FoM: 0.3221 / Elapsed time: 85 s
# Iteration: 57 / FoM: 0.3373 / Elapsed time: 86 s
# Iteration: 58 / FoM: 0.3529 / Elapsed time: 88 s
# Iteration: 59 / FoM: 0.369 / Elapsed time: 89 s
# Iteration: 60 / FoM: 0.3856 / Elapsed time: 90 s
# Iteration: 61 / FoM: 0.4026 / Elapsed time: 92 s
# Iteration: 62 / FoM: 0.4199 / Elapsed time: 93 s
# Iteration: 63 / FoM: 0.4376 / Elapsed time: 94 s
# Iteration: 64 / FoM: 0.4555 / Elapsed time: 96 s
# Iteration: 65 / FoM: 0.4736 / Elapsed time: 97 s
# Iteration: 66 / FoM: 0.4916 / Elapsed time: 98 s
# Iteration: 67 / FoM: 0.5096 / Elapsed time: 99 s
# Iteration: 68 / FoM: 0.5276 / Elapsed time: 101 s
# Iteration: 69 / FoM: 0.5452 / Elapsed time: 102 s
# Iteration: 70 / FoM: 0.5625 / Elapsed time: 103 s
# Iteration: 71 / FoM: 0.5794 / Elapsed time: 105 s
# Iteration: 72 / FoM: 0.5956 / Elapsed time: 106 s
# Iteration: 73 / FoM: 0.6111 / Elapsed time: 107 s
# Iteration: 74 / FoM: 0.626 / Elapsed time: 109 s
# Iteration: 75 / FoM: 0.6402 / Elapsed time: 110 s
# Iteration: 76 / FoM: 0.6534 / Elapsed time: 111 s
# Iteration: 77 / FoM: 0.6659 / Elapsed time: 113 s
# Iteration: 78 / FoM: 0.6775 / Elapsed time: 114 s
# Iteration: 79 / FoM: 0.6882 / Elapsed time: 115 s
# Iteration: 80 / FoM: 0.6982 / Elapsed time: 116 s
# Iteration: 81 / FoM: 0.7073 / Elapsed time: 118 s
# Iteration: 82 / FoM: 0.7157 / Elapsed time: 119 s
# Iteration: 83 / FoM: 0.7235 / Elapsed time: 120 s
# Iteration: 84 / FoM: 0.7306 / Elapsed time: 122 s
# Iteration: 85 / FoM: 0.7371 / Elapsed time: 123 s
# Iteration: 86 / FoM: 0.7432 / Elapsed time: 124 s
# Iteration: 87 / FoM: 0.7488 / Elapsed time: 126 s
# Iteration: 88 / FoM: 0.754 / Elapsed time: 127 s
# Iteration: 89 / FoM: 0.7588 / Elapsed time: 128 s
# Iteration: 90 / FoM: 0.7634 / Elapsed time: 129 s
# Iteration: 91 / FoM: 0.7677 / Elapsed time: 131 s
# Iteration: 92 / FoM: 0.7718 / Elapsed time: 132 s
# Iteration: 93 / FoM: 0.7757 / Elapsed time: 133 s
# Iteration: 94 / FoM: 0.7795 / Elapsed time: 135 s
# Iteration: 95 / FoM: 0.7831 / Elapsed time: 136 s
# Iteration: 96 / FoM: 0.7867 / Elapsed time: 137 s
# Iteration: 97 / FoM: 0.7903 / Elapsed time: 139 s
# Iteration: 98 / FoM: 0.7937 / Elapsed time: 140 s
# Iteration: 99 / FoM: 0.7971 / Elapsed time: 141 s
# Iteration: 100 / FoM: 0.8004 / Elapsed time: 142 s
# Iteration: 101 / FoM: 0.8038 / Elapsed time: 144 s
# Iteration: 102 / FoM: 0.8072 / Elapsed time: 145 s
# Iteration: 103 / FoM: 0.8106 / Elapsed time: 146 s
# Iteration: 104 / FoM: 0.8139 / Elapsed time: 148 s
# Iteration: 105 / FoM: 0.8173 / Elapsed time: 149 s
# Iteration: 106 / FoM: 0.8206 / Elapsed time: 150 s
# Iteration: 107 / FoM: 0.824 / Elapsed time: 151 s
# Iteration: 108 / FoM: 0.8274 / Elapsed time: 153 s
# Iteration: 109 / FoM: 0.8307 / Elapsed time: 154 s
# Iteration: 110 / FoM: 0.834 / Elapsed time: 155 s
# Iteration: 111 / FoM: 0.8373 / Elapsed time: 157 s
# Iteration: 112 / FoM: 0.8406 / Elapsed time: 158 s
# Iteration: 113 / FoM: 0.8438 / Elapsed time: 159 s
# Iteration: 114 / FoM: 0.847 / Elapsed time: 160 s
# Iteration: 115 / FoM: 0.8502 / Elapsed time: 162 s
# Iteration: 116 / FoM: 0.8533 / Elapsed time: 163 s
# Iteration: 117 / FoM: 0.8565 / Elapsed time: 164 s
# Iteration: 118 / FoM: 0.8596 / Elapsed time: 166 s
# Iteration: 119 / FoM: 0.8627 / Elapsed time: 167 s
# Iteration: 120 / FoM: 0.8658 / Elapsed time: 168 s
# Iteration: 121 / FoM: 0.8689 / Elapsed time: 169 s
# Iteration: 122 / FoM: 0.8721 / Elapsed time: 171 s
# Iteration: 123 / FoM: 0.8753 / Elapsed time: 172 s
# Iteration: 124 / FoM: 0.8785 / Elapsed time: 173 s
# Iteration: 125 / FoM: 0.8818 / Elapsed time: 175 s
# Iteration: 126 / FoM: 0.8851 / Elapsed time: 176 s
# Iteration: 127 / FoM: 0.8884 / Elapsed time: 177 s
# Iteration: 128 / FoM: 0.8917 / Elapsed time: 178 s
# Iteration: 129 / FoM: 0.8949 / Elapsed time: 180 s
# Iteration: 130 / FoM: 0.8982 / Elapsed time: 181 s
# Iteration: 131 / FoM: 0.9013 / Elapsed time: 182 s
# Iteration: 132 / FoM: 0.9045 / Elapsed time: 183 s
# Iteration: 133 / FoM: 0.9075 / Elapsed time: 185 s
# Iteration: 134 / FoM: 0.9106 / Elapsed time: 187 s
# Iteration: 135 / FoM: 0.9136 / Elapsed time: 188 s
# Iteration: 136 / FoM: 0.9165 / Elapsed time: 190 s
# Iteration: 137 / FoM: 0.9195 / Elapsed time: 191 s
# Iteration: 138 / FoM: 0.9224 / Elapsed time: 193 s
# Iteration: 139 / FoM: 0.9251 / Elapsed time: 194 s
# Iteration: 140 / FoM: 0.9279 / Elapsed time: 195 s
# Iteration: 141 / FoM: 0.9306 / Elapsed time: 196 s
# Iteration: 142 / FoM: 0.9332 / Elapsed time: 198 s
# Iteration: 143 / FoM: 0.9357 / Elapsed time: 199 s
# Iteration: 144 / FoM: 0.9381 / Elapsed time: 200 s
# Iteration: 145 / FoM: 0.9405 / Elapsed time: 202 s
# Iteration: 146 / FoM: 0.9428 / Elapsed time: 203 s
# Iteration: 147 / FoM: 0.945 / Elapsed time: 204 s
# Iteration: 148 / FoM: 0.9473 / Elapsed time: 205 s
# Iteration: 149 / FoM: 0.9494 / Elapsed time: 207 s
# Iteration: 150 / FoM: 0.9516 / Elapsed time: 208 s
# Iteration: 151 / FoM: 0.9538 / Elapsed time: 209 s
# Iteration: 152 / FoM: 0.9559 / Elapsed time: 210 s
# Iteration: 153 / FoM: 0.958 / Elapsed time: 212 s
# Iteration: 154 / FoM: 0.96 / Elapsed time: 213 s
# Iteration: 155 / FoM: 0.9621 / Elapsed time: 214 s
# Iteration: 156 / FoM: 0.9642 / Elapsed time: 215 s
# Iteration: 157 / FoM: 0.9662 / Elapsed time: 217 s
# Iteration: 158 / FoM: 0.9682 / Elapsed time: 218 s
# Iteration: 159 / FoM: 0.9703 / Elapsed time: 219 s
# Iteration: 160 / FoM: 0.9724 / Elapsed time: 221 s
# Iteration: 161 / FoM: 0.9744 / Elapsed time: 222 s
# Iteration: 162 / FoM: 0.9765 / Elapsed time: 223 s
# Iteration: 163 / FoM: 0.9786 / Elapsed time: 224 s
# Iteration: 164 / FoM: 0.9807 / Elapsed time: 226 s
# Iteration: 165 / FoM: 0.9829 / Elapsed time: 227 s
# Iteration: 166 / FoM: 0.9851 / Elapsed time: 228 s
# Iteration: 167 / FoM: 0.9872 / Elapsed time: 229 s
# Iteration: 168 / FoM: 0.9894 / Elapsed time: 231 s
# Iteration: 169 / FoM: 0.9916 / Elapsed time: 232 s
# Iteration: 170 / FoM: 0.9938 / Elapsed time: 233 s
# Iteration: 171 / FoM: 0.9961 / Elapsed time: 234 s
# Iteration: 172 / FoM: 0.9983 / Elapsed time: 236 s
# Iteration: 173 / FoM: 1.0005 / Elapsed time: 237 s
# Iteration: 174 / FoM: 1.0028 / Elapsed time: 238 s
# Iteration: 175 / FoM: 1.005 / Elapsed time: 239 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       9 rho_bar = torch.real(torch.fft.fftshift(torch.fft.ifft2(torch.fft.ifftshift(rho_fft*g_fft))))
#      10 rho_tilda = 1/2 + torch.tanh(2*beta[it]*rho_bar-beta[it])/(2*np.math.tanh(beta[it]))
# ---> 11 FoM = objective_function(rho_tilda)
#      13 optimizer.zero_grad()
#      14 (-FoM).backward() #gradient ascent
#
# Cell In[2], line 9, in objective_function(rho)
#       7 sim.set_incident_angle(inc_ang=inc_ang,azi_ang=azi_ang)
#       8 layer0_eps = rho*silicon_eps + (1.-rho)
# ----> 9 sim.add_layer(thickness=layer0_thickness,eps=layer0_eps)
#      10 sim.solve_global_smatrix()
#      11 t1xx = sim.S_parameters(orders=[1,0],direction='forward',port='transmission',polarization='xx',ref_order=[0,0])
#
# File ~/.local/lib/python3.10/site-packages/torcwa/rcwa.py:168, in rcwa.add_layer(self, thickness, eps, mu)
#     166     self._eigen_decomposition_homogenous(eps,mu)
#     167 else:
# --> 168     self._eigen_decomposition()
#     170 self._solve_layer_smatrix()
#
# File ~/.local/lib/python3.10/site-packages/torcwa/rcwa.py:1236, in rcwa._eigen_decomposition(self)
#    1234 # Eigen-decomposition
#    1235 if self.stable_eig_grad is True:
# -> 1236     kz_norm, E_eigvec = Eig.apply(torch.matmul(self.P[-1],self.Q[-1]))
#    1237 else:
#    1238     kz_norm, E_eigvec = torch.linalg.eig(torch.matmul(self.P[-1],self.Q[-1]))
#
# File ~/.local/lib/python3.10/site-packages/torcwa/torch_eig.py:14, in Eig.forward(ctx, x)
#      11 @staticmethod
#      12 def forward(ctx,x):
#      13     ctx.input = x
# ---> 14     eigval, eigvec = torch.linalg.eig(x)
#      15     ctx.eigval = eigval.cpu()
#      16     ctx.eigvec = eigvec.cpu()
#
# KeyboardInterrupt:

# %%
plt.plot(np.array(FoM_history))

# %%
# Export data
filename = 'Example6_data.mat'
ex6_data = {'rho_history':rho_history,'FoM_history':FoM_history}
scipy.io.savemat(filename,ex6_data)

# Plot
plt.imshow(rho_tilda.detach().cpu().numpy())
plt.colorbar()

# %%
# Field calculation
z = torch.linspace(-500,1500,501,device=device)
z_axis = z.cpu()

rho_fft = torch.fft.fftshift(torch.fft.fft2(torch.fft.ifftshift(rho)))
rho_bar = torch.real(torch.fft.fftshift(torch.fft.ifft2(torch.fft.ifftshift(rho_fft*g_fft))))
rho_tilda = 1/2 + torch.tanh(2*beta[-1]*rho.detach()-beta[-1])/(2*np.math.tanh(beta[-1]))

order = [15,8]

sim = torcwa.rcwa(freq=1/lamb0,order=order,L=L,dtype=sim_dtype,device=device)
sim.add_input_layer(eps=substrate_eps)
sim.set_incident_angle(inc_ang=inc_ang,azi_ang=azi_ang)
layer0_eps = rho_tilda*silicon_eps + (1.-rho_tilda)
sim.add_layer(thickness=layer0_thickness,eps=layer0_eps)
sim.solve_global_smatrix()

# %%
# View XZ-plane fields and export for x-pol input
sim.source_planewave(amplitude=[1.,0.],direction='forward')
[Ex, Ey, Ez], [Hx, Hy, Hz] = sim.field_xz(torcwa.rcwa_geo.x,z,L[1]/2)
Enorm = torch.sqrt(torch.abs(Ex)**2 + torch.abs(Ey)**2 + torch.abs(Ez)**2)
Hnorm = torch.sqrt(torch.abs(Hx)**2 + torch.abs(Hy)**2 + torch.abs(Hz)**2)

plt.figure(figsize=(10,12))
plt.imshow(torch.transpose(torch.real(Hy),-2,-1).cpu(),cmap='jet',origin='lower',extent=[x_axis[0],x_axis[-1],z_axis[0],z_axis[-1]])
plt.colorbar()

ex6_Xpol_data = {'x_axis':x_axis.numpy(),'y_axis':y_axis.numpy(),'z_axis':z_axis.numpy(),\
    'Ex':Ex.cpu().numpy(),'Ey':Ey.cpu().numpy(),'Ez':Ez.cpu().numpy(),'Enorm':Enorm.cpu().numpy(),\
    'Hx':Hx.cpu().numpy(),'Hy':Hy.cpu().numpy(),'Hz':Hz.cpu().numpy(),'Hnorm':Hnorm.cpu().numpy()}
scipy.io.savemat('Example6_Xpol_data.mat',ex6_Xpol_data)

# %%
# View XZ-plane fields and export for x-pol input
sim.source_planewave(amplitude=[0.,1.],direction='forward')
[Ex, Ey, Ez], [Hx, Hy, Hz] = sim.field_xz(torcwa.rcwa_geo.x,z,L[1]/2)
Enorm = torch.sqrt(torch.abs(Ex)**2 + torch.abs(Ey)**2 + torch.abs(Ez)**2)
Hnorm = torch.sqrt(torch.abs(Hx)**2 + torch.abs(Hy)**2 + torch.abs(Hz)**2)

plt.figure(figsize=(10,12))
plt.imshow(torch.transpose(torch.real(Ey),-2,-1).cpu(),cmap='jet',origin='lower',extent=[x_axis[0],x_axis[-1],z_axis[0],z_axis[-1]])
plt.colorbar()

ex6_Ypol_data = {'x_axis':x_axis.numpy(),'y_axis':y_axis.numpy(),'z_axis':z_axis.numpy(),\
    'Ex':Ex.cpu().numpy(),'Ey':Ey.cpu().numpy(),'Ez':Ez.cpu().numpy(),'Enorm':Enorm.cpu().numpy(),\
    'Hx':Hx.cpu().numpy(),'Hy':Hy.cpu().numpy(),'Hz':Hz.cpu().numpy(),'Hnorm':Hnorm.cpu().numpy()}
scipy.io.savemat('Example6_Ypol_data.mat',ex6_Ypol_data)
